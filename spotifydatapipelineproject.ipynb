# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import fcntions here
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
# Out:
# C:\Users\Madhavi\AppData\Local\Temp\ipykernel_26520\3536531384.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="29a32a023bf14b60b6085afd1ec325b6", client_secret="180375a3df4844f0a1708c007a8cd7e8")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#top playlist link everyday 9 am to extract
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
#extract playlist id from link text before ? and / split() string to list
playlist_link.split("/")
# Out:
# ['https:',
#  '',
#  'open.spotify.com',
#  'playlist',
#  '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f']

# %%
#need last element now use split to get list
playlist_link.split("/")[-1]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f'

# %%
#need first element now use split to get list
playlist_link.split("/")[-1].split("?")[0]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
#save it in variable, use finction playlist_tracks() and apss var will get long json data
playlist_URI = playlist_link.split("/")[-1].split('?')[0]
data = sp.playlist_tracks(playlist_URI)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
# spotify app has track/songs, album , artistinfo ; json track url, added by user , artist info id artist name type ; again uri name release date transofrm accroding to ur req
# messy data to be structured , we have data in items key
data['items']
# Out:
# [{'added_at': '2024-03-08T10:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#       'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#       'id': '22wbnEMDvgVIAGdFeek6ET',
#       'name': 'Benson Boone',
#       'type': 'artist',
#       'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
# we have album info inside list items- data['items'][0]
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#     'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#     'id': '22wbnEMDvgVIAGdFeek6ET',
#     'name': 'Benson Boone',
#     'type': 'artist',
#     'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
# ...

# %%
data['items'][0]['track']['album']['id']['name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data['items'][0]['track']['album']['id']['name']
#
# TypeError: string indices must be integers, not 'str'

# %%
# going data one by one and trying to extract what we need ; album href id, name, releasedate ,totaltracks, externalurls spotify
# data['items'][0]['track']['album']['id'], data['items'][0]['track']['album']['name'], data['items'][0]['track']['album']['release_date'], data['items'][0]['track']['album']['total_tracks'], data['items'][0]['track']['album']['external_urls']['spotify']

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
#   print(album_id) goes to each and every item and extracts
#   now convert this into dictionary to create a dataframe ; 
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
#    print dictionary
    print(album_element)
# Out:
# {'album_id': '29aSKB1qPEbN0Qf9OPSQpw', 'name': 'Beautiful Things', 'release_date': '2024-01-18', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'}
# {'album_id': '30zwjSQEodaUXCn11nmiVF', 'name': 'VULTURES 1', 'release_date': '2024-02-09', 'total_tracks': 16, 'url': 'https://open.spotify.com/album/30zwjSQEodaUXCn11nmiVF'}
# {'album_id': '4JDXBZdRPId4devseaAOKH', 'name': 'DECIDE', 'release_date': '2022-09-16', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'}
# {'album_id': '3UOV8XvCwMKaATRNXrYCjN', 'name': 'greedy', 'release_date': '2023-09-15', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'}
# {'album_id': '2NXwHjhgaAdkDy6GPSxMAd', 'name': "TEXAS HOLD 'EM", 'release_date': '2024-02-10', 'total_tracks': 3, 'url': 'https://open.spotify.com/album/2NXwHjhgaAdkDy6GPSxMAd'}
# ...

# %%
#  create list of dictionaries to make it more structure
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'name': 'Beautiful Things',
#   'release_date': '2024-01-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'name': 'VULTURES 1',
#   'release_date': '2024-02-09',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/30zwjSQEodaUXCn11nmiVF'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'name': 'DECIDE',
#   'release_date': '2022-09-16',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '2NXwHjhgaAdkDy6GPSxMAd',
#   'name': "TEXAS HOLD 'EM",
#   'release_date': '2024-02-10',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/2NXwHjhgaAdkDy6GPSxMAd'},
# ...

# %%
# nested jsons one track can have multiple artists , list of artists one-many relationship for key value below //multi disctinary loop
artist_list = []
for row in data['items']:
    for key, value in row.items(): 
        if key == "track":
            for artist in value['artists']:
                # print(artists) print(artist['id'])
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '4xPQFgDA5M2xa0ZGo5iIsv',
#   'artist_name': '¥$',
#   'external_url': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv'},
#  {'artist_id': '5K4W6rqBFWDnAN6FQUkS6x',
#   'artist_name': 'Kanye West',
#   'external_url': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x'},
#  {'artist_id': '7c0XG5cIJTrrAgEC3ULPiq',
#   'artist_name': 'Ty Dolla $ign',
#   'external_url': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq'},
#  {'artist_id': '1pPmIToKXyGdsCF6LmqLmI',
#   'artist_name': 'Rich The Kid',
#   'external_url': 'https://api.spotify.com/v1/artists/1pPmIToKXyGdsCF6LmqLmI'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '5p9HO3XC5P3BLxJs5Mtrhm',
# ...

# %%
# nested jsons one track can have multiple artists , list of artists one-many relationship
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6tNQ70jh4OwmPGpYy6R2o9',
#   'song_name': 'Beautiful Things',
#   'duration_ms': 180304,
#   'url': 'https://open.spotify.com/track/6tNQ70jh4OwmPGpYy6R2o9',
#   'popularity': 100,
#   'song_added': '2024-03-08T10:10:49Z',
#   'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '3w0w2T288dec0mgeZZqoNN',
#   'song_name': 'CARNIVAL',
#   'duration_ms': 264324,
#   'url': 'https://open.spotify.com/track/3w0w2T288dec0mgeZZqoNN',
#   'popularity': 96,
#   'song_added': '2024-03-08T10:10:49Z',
#   'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'artist_id': '4xPQFgDA5M2xa0ZGo5iIsv'},
#  {'song_id': '3qhlB30KknSejmIvZZLjOD',
#   'song_name': 'End of Beginning',
#   'duration_ms': 159245,
#   'url': 'https://open.spotify.com/track/3qhlB30KknSejmIvZZLjOD',
#   'popularity': 94,
#   'song_added': '2024-03-08T10:10:49Z',
#   'album_id': '4JDXBZdRPId4devseaAOKH',
#   'artist_id': '5p9HO3XC5P3BLxJs5Mtrhm'},
# ...

# %%
# now convert this into proper dataframe
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id              name release_date  total_tracks  \
# 0  29aSKB1qPEbN0Qf9OPSQpw  Beautiful Things   2024-01-18             1
# 1  30zwjSQEodaUXCn11nmiVF        VULTURES 1   2024-02-09            16
# 2  4JDXBZdRPId4devseaAOKH            DECIDE   2022-09-16            13
# 3  3UOV8XvCwMKaATRNXrYCjN            greedy   2023-09-15             1
# 4  2NXwHjhgaAdkDy6GPSxMAd    TEXAS HOLD 'EM   2024-02-10             3
#
#                                                  url
# 0  https://open.spotify.com/album/29aSKB1qPEbN0Qf...
# 1  https://open.spotify.com/album/30zwjSQEodaUXCn...
# 2  https://open.spotify.com/album/4JDXBZdRPId4dev...
# 3  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 4  https://open.spotify.com/album/2NXwHjhgaAdkDy6...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# plan for any other transformations required release_date object to dateformat, int pk ensure unique records
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id         song_name  duration_ms  \
# 0  6tNQ70jh4OwmPGpYy6R2o9  Beautiful Things       180304
# 1  3w0w2T288dec0mgeZZqoNN          CARNIVAL       264324
# 2  3qhlB30KknSejmIvZZLjOD  End of Beginning       159245
# 3  3rUGC1vUpkDG9CZFHMur1t            greedy       131872
# 4  7AYmToZ5y67fBjq4RLFbuq    TEXAS HOLD 'EM       235636
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6tNQ70jh4OwmPGp...         100
# 1  https://open.spotify.com/track/3w0w2T288dec0mg...          96
# 2  https://open.spotify.com/track/3qhlB30KknSejmI...          94
# 3  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...          98
# 4  https://open.spotify.com/track/7AYmToZ5y67fBjq...          87
#
#              song_added                album_id               artist_id
# 0  2024-03-08T10:10:49Z  29aSKB1qPEbN0Qf9OPSQpw  22wbnEMDvgVIAGdFeek6ET
# 1  2024-03-08T10:10:49Z  30zwjSQEodaUXCn11nmiVF  4xPQFgDA5M2xa0ZGo5iIsv
# ...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  22wbnEMDvgVIAGdFeek6ET   Benson Boone
# 1  4xPQFgDA5M2xa0ZGo5iIsv             ¥$
# 2  5K4W6rqBFWDnAN6FQUkS6x     Kanye West
# 3  7c0XG5cIJTrrAgEC3ULPiq  Ty Dolla $ign
# 4  1pPmIToKXyGdsCF6LmqLmI   Rich The Kid
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 1  https://api.spotify.com/v1/artists/4xPQFgDA5M2...
# 2  https://api.spotify.com/v1/artists/5K4W6rqBFWD...
# 3  https://api.spotify.com/v1/artists/7c0XG5cIJTr...
# 4  https://api.spotify.com/v1/artists/1pPmIToKXyG...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
